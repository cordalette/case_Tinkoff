# %% [markdown]
# # Кейс для бизнес-аналитиков (технологов)

# %% [markdown]
# Предположим, появилась инициатива по созданию мобильного приложения Тинькофф.Спорт, в котором будут объединяться программы тренировок и питания, напоминания, полезные статьи из Тинькофф.Журнал на тему «спорт» и выгодные предложения от наших партнёров на эту тематику. Ты входишь в эту команду в роли бизнес-аналитика и владелец продукта просит тебя проанализировать потребности пользователей и подготовить презентацию, которая будет содержать в себе основной бизнес-контекст этого продукта
# Что может быть в этом материале:
#
# Что может быть в этом материале:
#
# 1.      Список user-story. Например, что-то основное типа «записаться на программу тренировки» или менее важное типа «заказать спортивное питание».
#
# 2.      Схема бизнес-процесса в рамках какой-либо (желательно не из 2-3 шагов 😊) user-story (можно как в рамках какой-либо нотации, так и без неё) с помощью любого инструмента;
#
# 3.      Набросок интерфейса пользователя;
#
# 4.      Верхнеуровневый список функциональных и нефункциональных требований;
#
# 5.      Какие-то показатели/индикаторы, по которым предлагается оценивать эффективность проекта;
#
# 6.      Что-то другое, что тебе кажется правильным включить?

# %% [markdown]
# ## Бизнес- контекст продукта

# %% [markdown]
# Начнем с краткого описания бизнес- контекста продукта, чтобы лучше понимать, как он встраивается в бизнес- процессы и стратегию компаниии, наметим цели нового продукта, целевую аудиторию его пользователей и конкурентов
#
# ####  1. **Цели продукта**:
# Цель заключается в создании мобильного приложения для здорового образа жизни, которое предоставляет инструменты и информацию для занятий спортом и ведения здорового образа жизни, в котором будут объединяться программы тренировок и питания, различные напоминания, полезные статьи из Тинькофф.Журнал на тему «спорт» и выгодные предложения от партнёров на эту тематику
#
# ####  2. **Целевая аудитория**:
# - Тренеры для подготовки программ тренировок
# - Профессиональные спортсмены
# - Спортсмены-любители
# - Начинающие спортсмены, нуждающиеся в руководствах
# - Люди, стремящиеся вести здоровый образ жизни
# - Люди, которым интересны новости спорта
# - Люди с ограниченными физическими возможностями
# - Туристы и путешественники для возможности узнавать об активностях и местах занятий спортом в разных городах
# - Спортивные команды для возможности отслеживать тренировочный процесс друг друга
# - Корпоративные клиенты для поддержки физической активности и ЗОЖ среди сотрудников
#
# ####  3. **Основные конкуренты**:
# - Strava
# - Jefit
# - Gym Boom
# - Карманный тренер
# - WODster

# %% [markdown]
# ## 1. Список user- story

# %% [markdown]
# Список user story - это инструмент, используемый в методологии разработки программного обеспечения Agile для описания функциональных требований к продукту или приложению с точки зрения пользователей. Каждая user story представляет собой короткое описание конкретной функциональности или возможности продукта, которое фокусируется на потребностях и целях пользователей.
#
# Каждая user- story должна иметь название, описание, критерии приемки, приоритет реализации и примерную оценку ресурсов (временных, денежных и тд), требуемых на ее реализацию
#
# В контексте данного кейса ограничимся названиями и описаниями. Итак, основные функции и user- story

# %% [markdown]
# ####  1. **Регистрация и профиль пользователя**:
#  Как пользователь приложения "Тинькофф.Спорт" я должен иметь возможность создать учетную запись (профиль) в приложении для доступа ко всем функциям и персонализированным рекомендациям. Процесс регистрации и профилирования пользователя должен быть интуитивно понятным и безопасным
#
# - **Регистрация**: возможность регистрации и авторизации в приложении по номеру телефона/ e-mail/ через аккаунт в соц.сети/ через аккаунт Google
# - **Безопасность**: должна обеспечиваться приемлемая безопасность личных данных пользователя
# - **Управление профилем**: пользователь должен иметь доступ к функциональности управления своим профилем, включая редактирование информации, изменение пароля и удаление аккаунта
# - **Соглашение с условиями использования**: при регистрации пользователь должен соглашаться с условиями использования и политикой конфиденциальности приложения
#
#
#
# ####  2. **Подбор программ тренировок**:
# Как пользователь приложения "Тинькофф.Спорт", я хочу иметь возможность выбрать и подписаться на программу тренировок, которая соответствует моим целям и уровню физической подготовки. Я хочу, чтобы процесс выбора программы был удобным и персонализированным, а также обеспечивал максимальную эффективность в достижении спортивных целей
#
# - **Выбор целей**: пользователь может указать свои спортивные цели, такие как снижение веса, увеличение мышечной массы, улучшение выносливости и т. д. Важно, чтобы пользователь мог выбрать несколько целей или одну главную цель.
# - **Оценка уровня физической подготовки**: пользователь оценивает свой текущий уровень физической подготовки, например, начинающий, средний или продвинутый. Это помогает предоставить более подходящие программы тренировок.
# - **Рекомендации**:  на основе выбранных целей и уровня подготовки, приложение предоставляет рекомендации по подходящим программам тренировок. Эти рекомендации могут включать в себя описания программ, ожидаемые результаты и рейтинг от других пользователей.
# - **Просмотр и выбор программы**: пользователь может просматривать доступные программы тренировок, фильтровать их по типу спорта, продолжительности, интенсивности и другим параметрам, а затем выбирать те, которые ему интересны
# - **Подписка и начало тренировок**: после выбора программы пользователь может подписаться на нее и начать тренировки. Приложение предоставляет доступ к расписанию тренировок, видеоурокам и инструкциям.
#
#
#
# ####  3. **Питание и диета**:
# Как пользователь приложения "Тинькофф.Спорт", я хочу иметь возможность выбрать и подписаться на программу тренировок, которая соответствует моим целям и уровню физической подготовки. Я хочу, чтобы процесс выбора программы был удобным и персонализированным, а также обеспечивал максимальную эффективность в достижении спортивных целей
#
# - **Профиль питания**: пользователь может заполнить профиль питания, указав свои диетические предпочтения и ограничения
# - **Цели по питанию**: пользователь может установить диетические цели, такие как снижение калорий, контроль веса, увеличение белка и тд
# - **Рекомендации по продуктам**: на основе профиля питания и целей, приложение предоставляет рекомендации по здоровым продуктам и ингредиентам
# - **Рецепты и блюда**: пользователь может получать рецепты блюд, соответствующих его диетическим предпочтениям и целям
# - **Расчет калорий и пищевой ценности**: приложение позволяет пользователю отслеживать потребляемые калории, белки, жиры, углеводы и другие пищевые параметры для более точного учета питания
# - **Мониторинг питания**: пользователь может вести журнал питания, фиксируя потребляемые блюда и напитки, чтобы оценивать свое соблюдение диетических целей
# - **Уведомления и напоминания**: приложение предоставляет уведомления и напоминания о времени приема пищи и других событиях, связанных с питание
# - **Заказ питания**: приложение предоставляет возможность выбрать и заказать спортивное питание
#
#
#
# ####  4. **Уведомления и напоминания**:
# Как пользователь приложения "Тинькофф.Спорт", я хочу иметь возможность устанавливать персонализированные напоминания и получать уведомления, чтобы поддерживать мотивацию, планировать активности и не упускать важные моменты в своем тренировчном процессе
#
# - **Настройка напоминаний**: пользователь может настраивать различные виды напоминаний, такие как напоминания о тренировках, приеме пищи, питье воды, выполнении зарядки и других активностях
# - **Уведомления о тренировках**: приложение отправляет уведомления о предстоящих тренировках, включая информацию о типе тренировки, времени начала и необходимом оборудовании
# - **Уведомления о достижениях**: приложение отправляет уведомления о достижениях и прогрессе пользователя
# - **Гибкость и настройки**: пользователь может настраивать, какие уведомления и напоминания он хочет получать, и имеет возможность временно отключать их
#
#
#
# ####  5. **Статьи и советы**:
# Как пользователь приложения "Тинькофф.Спорт", я хочу иметь доступ к разнообразным и качественным статьям и советам на тему спорта, фитнеса, здоровья и здорового образа жизни
#
# - **Доступ к каталогу статей и советов**: приложение предоставляет пользователю каталог статей и советов, сгруппированный по темам, таким как тренировки, питание, здоровье и тд
# - **Персонализированные рекомендации**: на основе профиля пользователя, его интересов и предпочтений, приложение предлагает персонализированные рекомендации по статьям и советам, которые могут быть наиболее полезными
# - **Чтение и сохранение**: пользователь может читать статьи и советы прямо в приложении, а также сохранять интересные материалы для последующего доступа без интернета
# - **Уведомления о новых публикациях**: приложение отправляет уведомления о новых статьях и советах в соответствии с интересами пользователя
#
#
#
# ####  6. **Предложения от партнеров**:
# Как пользователь приложения "Тинькофф.Спорт", я хочу иметь возможность получать персонализированные предложения и скидки от партнеров, связанных со спортом, фитнесом и здоровым образом жизни
#
# - **Доступ к партнерской сети**: приложение имеет партнерскую сеть, в которой собраны компании и бренды, предлагающие продукты и услуги, связанные со спортом и здоровым образом жизни.
# - **Персонализированные рекомендации**: на основе данных из профиля пользователя и его активности в приложении (например, тренировки, питание), приложение предоставляет персонализированные предложения и скидки от партнеров
# - **Уведомления о скидках**:  Пользователь может получать уведомления о новых скидках и предложениях, которые могут быть интересны
# - **Обратная связь**: пользователь может оценивать и оставлять отзывы о предложениях и скидках, что помогает другим пользователям делать более информированный выбор

# %% [markdown]
# ## 2. Схема бизнес- процесса в рамках одной из user- story

# %% [markdown]
# Рассмотрим бизнес- процесс в рамках user- story **Настройка напоминаний**
#
# Бизнес-процесс в рамках этой user story описывает последовательность шагов и действий, необходимых для того, чтобы пользователь мог настроить свои индивидуальные напоминания в приложении "Тинькофф.Спорт"

# %% [markdown]
# - Пользователь открывает приложение "Тинькофф.Спорт"
# - Переходит в раздел с напоминаниями
# - Выбирает тип напоминания из таких как: прием пищи, тренировка, необходимость размяться и тд
# - Для каждого выбранного типа пользователь настраивает параметры напоминания
#     Время
#     Частоту напоминаний (ежедневно, по выбранным дням недели, в конкретные даты (в этом случае стоит реализовать календарь для удобства))
# - Пользователь сохраняет свои настройки напоминаний и в дальнейшем получает их

# %% [markdown]
# ## 3. Нефункциональные требования к продукту

# %% [markdown]
# Так как большинство функциональных требований я описал в разделе о списке user story, в этом разделе остановимся на нефункциональных требованиях, то есть таких, которые описывают характеристики и ограничения продукта, но не являются прямо связанными с его функциональностью

# %% [markdown]
# ####  1. **Производительность**:
#
# - **Время отклика**: приложение должно обеспечивать плавные переходы между разделами, работать без зависаний, скажем, время отклика на любое действие пользователя не должно превышать 1 с.
# - **Масштабируемость**: приложение должно оставаться стабильным при росте числа пользователей и данных о них
# - **Экономия заряда батареи**: приложение должно экономно расходовать заряд аккумулятора устройства
# - **Малый вес**: приложение не должно весить слишком много, скажем, меньше 100 Мб
#
#
# ####  2. **Безопасность**:
#
# - **Шифрование данных**: личная информация пользователей, включая данные о профилях, платежах (например, оплатах различных подписок) и здоровье, должна храниться и передаваться с использованием современных методов шифрования для защиты от несанкционированного доступа
# - **Защита от взлома**: приложение должно иметь защитные меры для предотвращения взлома и атак, включая защиту от SQL-инъекций и скрытых уязвимостей
#
#
# ####  3. **Доступность для всех**:
#
# - **Совместимость с ассистивными технологиями**: приложение должно быть доступным для пользователей с ограниченными возможностями и совместимым с ассистивными технологиями, такими как голосовые помощники
# - **Удобочитаемость интерфейса**: приложение должно поддерживать возможность изменять размер и контрастность шрифта, иметь возможность перехода в ночной режим (темные тона, отсутствие ярких элементов интерфейса)

# %% [markdown]
# ## 4. Метрики эффективности проекта

# %% [markdown]
# Мы можем использовать такие метрики, как
#
# - **DAU** - количество уникальных активных пользователей в приложении за день
# - **MAU** - -/- за месяц
# - **WAU** - -/- за неделю
# - **Retention rate** - процент пользователей, которые возвращаются и продолжают использовать приложение после первой установки
# - **Количество сессий** - сколько раз пользователи запускают приложение
# - **Среднее время в приложении** - сколько времени пользователи проводят в приложении за одну сессию
# - **Конверсия по ключевым действиям** -  процент пользователей, которые выполняют целевые действия, такие как регистрация или покупка подписки
# - **Оценки и отзывы** - сколько времени пользователи проводят в приложении за одну сессию
# - **Количество подписок** -  процент пользователей, которые выполняют целевые действия, такие как регистрация или покупка подписки
# - **ARPU** - cредний доход от каждого пользователя
# - **LTV** -  прогнозируемая прибыль от пользователя на протяжении всего времени использования приложения
#
# Из метрик, касающихся нефункциональных требований к приложению, можно выделить
#
# - **Скорость загрузки приложения**
# - **Время доступности приложения** - процент времени, в течение которого приложение доступно и функционирует без сбоев

# %% [markdown]
# ## 5. Монетизация продукта

# %% [markdown]
# Монетизировать продукт можно множеством различных способов, приведем некоторые из них

# %% [markdown]
# ####  1. **Подписки**:
#
# - **Премиум- подписка**: пользователи могут оформить ежемесячную или годовую подписку, которая дает им доступ к дополнительным функциям и контенту, таким как персонализированные тренировки и планы питания, эксклюзивные статьи и советы, расширенная статистика и отчетность. Стоит ввести демо- версию функционала премиум- подписки
#
#
# ####  2. **Продажа контента**:
#
# - **Продажа тренировочных программ**: пользователь может покупать отдельные тренировочные программы или планы питания, созданные тренерами индивидуально для него
#
#
# ####  3. **Рекламная модель**:
#
# - **Показ рекламы**
# - **Спонсорство и партнерство**: сотрудничество с фитнес-брендами и спортивными компаниями для показа их продукции и акций
#
#
# ####  4. **Партнерские программы**:
#
# - **Предложения и скидки от партнеров**: получение комиссии с партнеров за предоставление пользователям специальных предложений и скидок
#
# ####  5. **Интернет-магазин**:
#
#
# - **Продажа мерча**
# - **Продажа спортивного оборудования**
# - **Продажа спортивного питания**
#
# ####  6. **Консультации и тренировки**:
#
# - **Онлайн-консультации**: возможность проводить онлайн- консультации с опытными тренерами и диетологами
